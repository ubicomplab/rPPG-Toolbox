# %%
import pandas as pd
import numpy as np
import

# %%
data_out_path = '../PURE_PURE_UBFC_deepphys_outputs.pickle'
with open(data_out_path, 'rb') as f:
    data = pd.read_pickle(f)

# %%
data.keys()
# Out:
# dict_keys(['predictions', 'labels', 'label_type', 'fs'])

# %%
data['predictions']['subject1'][0]
# Out:
# tensor([[ 2.1013e-01],
#         [-1.8140e-01],
#         [ 1.5649e-01],
#         [-1.0781e-01],
#         [-1.7086e-01],
#         [ 4.0960e-01],
#         [-2.6359e-01],
#         [ 1.2334e-01],
#         [-2.4081e-01],
#         [-8.7073e-02],
#         [ 1.4824e-01],
#         [-3.1390e-01],
#         [-2.8118e-01],
#         [ 4.2108e-01],
#         [-2.4854e-01],
#         [-3.3151e-01],
#         [-1.4578e-01],
#         [-1.5499e-01],
#         [-2.0938e-01],
#         [-8.2700e-02],
#         [-9.7990e-02],
#         [ 3.5109e-01],
#         [-6.1402e-02],
#         [-1.0678e-01],
#         [-3.2254e-01],
#         [-2.1689e-01],
#         [-1.7429e-01],
#         [ 4.2468e-05],
#         [-1.2353e-01],
#         [ 5.0653e-02],
#         [ 3.8379e-01],
#         [-9.7228e-02],
#         [ 7.2867e-02],
#         [-1.9505e-01],
#         [-1.8247e-01],
#         [-1.3501e-01],
#         [-2.5295e-01],
#         [ 5.1201e-02],
#         [-3.5652e-01],
#         [-1.5513e-01],
# ...
